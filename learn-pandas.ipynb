# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("/home/chaudha4/Projects/pyprojects/python-projects/data_analysis/ch02-demographic_data_analyzer/adult.data.csv")
print("\n1 - Shape", df.shape)
print("\n1 - Shape", df.shape[0], df.shape[1])
# Out:
# 1 - Shape (32561, 15)
#
# 1 - Shape 32561 15

# %%
df
# Out:
#        age         workclass  fnlwgt   education  education-num  \
# 0       39         State-gov   77516   Bachelors             13
# 1       50  Self-emp-not-inc   83311   Bachelors             13
# 2       38           Private  215646     HS-grad              9
# 3       53           Private  234721        11th              7
# 4       28           Private  338409   Bachelors             13
# ...    ...               ...     ...         ...            ...
# 32556   27           Private  257302  Assoc-acdm             12
# 32557   40           Private  154374     HS-grad              9
# 32558   58           Private  151910     HS-grad              9
# 32559   22           Private  201490     HS-grad              9
# 32560   52      Self-emp-inc  287927     HS-grad              9
#
#            marital-status         occupation   relationship   race     sex  \
# 0           Never-married       Adm-clerical  Not-in-family  White    Male
# ...

# %%
# How many of each race are represented in this dataset

print("\n1 - ", df.groupby(by="race"))
print("\n2 - ", df.groupby(by="race").size())
print("\n3 - ", df.groupby(by="race").size().count())
# Out:
# 1 -  <pandas.core.groupby.generic.DataFrameGroupBy object at 0x7ff1f8449b20>
#
# 2 -  race
# Amer-Indian-Eskimo      311
# Asian-Pac-Islander     1039
# Black                  3124
# Other                   271
# White                 27816
# dtype: int64
#
# 3 -  5

# %%
# What is the average age of men?

df[(df.sex == "Male")].age.mean()
# Out:
# 39.43354749885268

# %%
df.age.count()
# Out:
# 32561

# %%
df[df.age > 10]
# Out:
#        age         workclass  fnlwgt   education  education-num  \
# 0       39         State-gov   77516   Bachelors             13
# 1       50  Self-emp-not-inc   83311   Bachelors             13
# 2       38           Private  215646     HS-grad              9
# 3       53           Private  234721        11th              7
# 4       28           Private  338409   Bachelors             13
# ...    ...               ...     ...         ...            ...
# 32556   27           Private  257302  Assoc-acdm             12
# 32557   40           Private  154374     HS-grad              9
# 32558   58           Private  151910     HS-grad              9
# 32559   22           Private  201490     HS-grad              9
# 32560   52      Self-emp-inc  287927     HS-grad              9
#
#            marital-status         occupation   relationship   race     sex  \
# 0           Never-married       Adm-clerical  Not-in-family  White    Male
# ...

# %%
df.race.value_counts().tolist()
# Out:
# [27816, 3124, 1039, 311, 271]

# %%
df[df.sex == "Male"].age.mean()
# Out:
# 39.43354749885268

# %%
df1 = df[ ~ df.education.isin(["Bachelors", "Masters", "Doctorate"]) ]
df2 = df1[df1.salary == ">50K"]
df
# Out:
#        age         workclass  fnlwgt   education  education-num  \
# 0       39         State-gov   77516   Bachelors             13
# 1       50  Self-emp-not-inc   83311   Bachelors             13
# 2       38           Private  215646     HS-grad              9
# 3       53           Private  234721        11th              7
# 4       28           Private  338409   Bachelors             13
# ...    ...               ...     ...         ...            ...
# 32556   27           Private  257302  Assoc-acdm             12
# 32557   40           Private  154374     HS-grad              9
# 32558   58           Private  151910     HS-grad              9
# 32559   22           Private  201490     HS-grad              9
# 32560   52      Self-emp-inc  287927     HS-grad              9
#
#            marital-status         occupation   relationship   race     sex  \
# 0           Never-married       Adm-clerical  Not-in-family  White    Male
# ...

# %%
min_work_hours = df["hours-per-week"].min()
df[ df["hours-per-week"] == min_work_hours ]
df["hours-per-week"] == min_work_hours
df[ (df["hours-per-week"] == min_work_hours) & (df.salary == ">50K")]
# Out:
#        age  workclass  fnlwgt  education  education-num      marital-status  \
# 189     58  State-gov  109567  Doctorate             16  Married-civ-spouse
# 20072   65          ?   76043    HS-grad              9  Married-civ-spouse
#
#            occupation relationship   race   sex  capital-gain  capital-loss  \
# 189    Prof-specialty      Husband  White  Male             0             0
# 20072               ?      Husband  White  Male             0             0
#
#        hours-per-week native-country salary
# 189                 1  United-States   >50K
# 20072               1  United-States   >50K

# %%
df1 = df.groupby(by="native-country").size()

df2 = df[(df.salary == ">50K")].groupby(by="native-country").size()

df3 = (df2 / df1) * 100

df3["India"]

df3.max()

df3.idxmax()
# Out:
# 'Iran'

# %%
df1 = df[(df.salary == ">50K") & (df["native-country"] == "India")]
df1.groupby(by="occupation").size()
df1.groupby(by="occupation").size().idxmax()
# Out:
# 'Prof-specialty'
